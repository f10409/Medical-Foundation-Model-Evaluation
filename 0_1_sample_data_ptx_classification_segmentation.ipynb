# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./inputs/SIIM_ACR_input.csv')
df
# Out:
#          PID                                            ImageId  \
# 0          0  1.2.276.0.7230010.3.1.4.8323329.5597.151787518...
# 1          1  1.2.276.0.7230010.3.1.4.8323329.12515.15178752...
# 2          2  1.2.276.0.7230010.3.1.4.8323329.4904.151787518...
# 3          3  1.2.276.0.7230010.3.1.4.8323329.32579.15178751...
# 4          7  1.2.276.0.7230010.3.1.4.8323329.1314.151787516...
# ...      ...                                                ...
# 10670  11575  1.2.276.0.7230010.3.1.4.8323329.32459.15178751...
# 10671  11576  1.2.276.0.7230010.3.1.4.8323329.4461.151787518...
# 10672  11579  1.2.276.0.7230010.3.1.4.8323329.32730.15178751...
# 10673  11580  1.2.276.0.7230010.3.1.4.8323329.13252.15178752...
# 10674  11581  1.2.276.0.7230010.3.1.4.8323329.12050.15178752...
#
#                                                DicomPath  Pneumothorax  \
# 0      /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 1      /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 2      /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 3      /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 4      /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# ...                                                  ...           ...
# 10670  /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 10671  /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 10672  /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 10673  /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 10674  /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
#
#                                                ImagePath
# 0      1.2.276.0.7230010.3.1.4.8323329.5597.151787518...
# 1      1.2.276.0.7230010.3.1.4.8323329.12515.15178752...
# 2      1.2.276.0.7230010.3.1.4.8323329.4904.151787518...
# 3      1.2.276.0.7230010.3.1.4.8323329.32579.15178751...
# 4      1.2.276.0.7230010.3.1.4.8323329.1314.151787516...
# ...                                                  ...
# 10670  1.2.276.0.7230010.3.1.4.8323329.32459.15178751...
# 10671  1.2.276.0.7230010.3.1.4.8323329.4461.151787518...
# 10672  1.2.276.0.7230010.3.1.4.8323329.32730.15178751...
# 10673  1.2.276.0.7230010.3.1.4.8323329.13252.15178752...
# 10674  1.2.276.0.7230010.3.1.4.8323329.12050.15178752...
#
# [10675 rows x 5 columns]

# %%
df.Pneumothorax.value_counts()
# Out:
# Pneumothorax
# 0    8296
# 1    2379
# Name: count, dtype: int64

# %%
df_balanced = df.groupby('Pneumothorax').sample(n=2379, random_state=5656)
df_balanced
# Out:
#          PID                                            ImageId  \
# 2841    3527  1.2.276.0.7230010.3.1.4.8323329.31882.15178751...
# 7689    8566  1.2.276.0.7230010.3.1.4.8323329.4785.151787518...
# 7038    7907  1.2.276.0.7230010.3.1.4.8323329.5314.151787518...
# 9528   10433  1.2.276.0.7230010.3.1.4.8323329.13394.15178752...
# 10381  11286  1.2.276.0.7230010.3.1.4.8323329.11080.15178752...
# ...      ...                                                ...
# 5743    6589  1.2.276.0.7230010.3.1.4.8323329.3159.151787517...
# 1718    2190  1.2.276.0.7230010.3.1.4.8323329.14168.15178752...
# 443      610  1.2.276.0.7230010.3.1.4.8323329.32242.15178751...
# 1976    2512  1.2.276.0.7230010.3.1.4.8323329.31695.15178751...
# 2052    2605  1.2.276.0.7230010.3.1.4.8323329.14431.15178752...
#
#                                                DicomPath  Pneumothorax  \
# 2841   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 7689   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 7038   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 9528   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# 10381  /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             0
# ...                                                  ...           ...
# 5743   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 1718   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 443    /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 1976   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
# 2052   /dicom-images-train/1.2.276.0.7230010.3.1.2.83...             1
#
#                                                ImagePath
# 2841   1.2.276.0.7230010.3.1.4.8323329.31882.15178751...
# 7689   1.2.276.0.7230010.3.1.4.8323329.4785.151787518...
# 7038   1.2.276.0.7230010.3.1.4.8323329.5314.151787518...
# 9528   1.2.276.0.7230010.3.1.4.8323329.13394.15178752...
# 10381  1.2.276.0.7230010.3.1.4.8323329.11080.15178752...
# ...                                                  ...
# 5743   1.2.276.0.7230010.3.1.4.8323329.3159.151787517...
# 1718   1.2.276.0.7230010.3.1.4.8323329.14168.15178752...
# 443    1.2.276.0.7230010.3.1.4.8323329.32242.15178751...
# 1976   1.2.276.0.7230010.3.1.4.8323329.31695.15178751...
# 2052   1.2.276.0.7230010.3.1.4.8323329.14431.15178752...
#
# [4758 rows x 5 columns]

# %%
# Shuffle the dataframe
df_balanced = df_balanced.sample(frac=1, random_state=5656).reset_index(drop=True)

# Calculate total samples and samples per fold
n_total = len(df_balanced)
n_per_fold = n_total // 5
remainder = n_total % 5

# Create fold assignments
fold_assignments = []
for fold in range(5):
    # Add one extra sample to first 'remainder' folds to handle uneven division
    fold_size = n_per_fold + (1 if fold < remainder else 0)
    fold_assignments.extend([fold] * fold_size)

# Assign fold numbers to the dataframe
df_balanced['Fold'] = fold_assignments

# Generate 5 files for cross-validation
for fold in range(5):
    # Create a copy of the dataframe
    df_fold = df_balanced.copy()
    
    # Create Split column based on current fold
    # Current fold becomes 'Test'
    # For remaining data, use similar proportions as your original code (75% train, 25% valid)
    def assign_split(fold_num):
        if fold_num == fold:
            return 'Test'
        elif fold_num == (fold + 1) % 5:  # Next fold becomes validation
            return 'Valid'
        else:
            return 'Train'
    
    df_fold['Split'] = df_fold['Fold'].apply(assign_split)
    
    # Save to file
    df_fold.to_csv(f'./inputs/input_train_ptx_cla_{fold}.csv', index=False)
    
    # Print split distribution for verification
    split_counts = df_fold['Split'].value_counts()
    print(f"Fold {fold + 1} - Train: {split_counts.get('Train', 0)}, "
          f"Valid: {split_counts.get('Valid', 0)}, Test: {split_counts.get('Test', 0)}")
# Out:
# Fold 1 - Train: 2854, Valid: 952, Test: 952
# Fold 2 - Train: 2854, Valid: 952, Test: 952
# Fold 3 - Train: 2855, Valid: 951, Test: 952
# Fold 4 - Train: 2856, Valid: 951, Test: 951
# Fold 5 - Train: 2855, Valid: 952, Test: 951

# %%
# # Shuffle the dataframe
# df_balanced = df_balanced.sample(frac=1, random_state=5656).reset_index(drop=True)

# # Calculate split indices to ensure exact proportions
# n_total = len(df_balanced)
# n_train = int(n_total * 0.6)
# n_valid = int(n_total * 0.2)
# n_test = n_total - n_train - n_valid  # Ensures all samples are assigned

# # Create split labels using numpy for better performance
# split_labels = np.concatenate([
#     ['Train'] * n_train,
#     ['Valid'] * n_valid,
#     ['Test'] * n_test
# ])

# # Assign splits
# df_balanced['Split'] = split_labels

# %%
# df_balanced

# %%
# df_balanced.to_csv('input_train_cla.csv', index=False)
