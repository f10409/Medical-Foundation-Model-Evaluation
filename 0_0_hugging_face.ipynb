# %% [markdown]
# ## Hugging Face Authentication
# 1. Sign up / log in Hugging Face (https://huggingface.co/google/medsiglip-448)<br>
# <img src="./notebook_figs/HF_login.png" alt="login" width="750"><br>
# 2. Create your Access Token (https://huggingface.co/settings/tokens)<br>
# <img src="./notebook_figs/HF_access0.png" alt="access0" width="750"><br>
# 3. Create "Read" Access Token<br>
# <img src="./notebook_figs/HF_access1.png" alt="access1" width="750"><br>
# 4. Copy your token<br>
# <img src="./notebook_figs/HF_token.png" alt="token" width="500"><br>
# 5. Save your token in keys.py<br>

# %% [markdown]
# ### Authenticate with Hugging Face

# %%
# from huggingface_hub import logout
# logout()

# %%
# Authenticate user for HuggingFace if needed. Enter token below if requested.
from huggingface_hub.utils import HfFolder

if HfFolder.get_token() is None:
    from huggingface_hub import notebook_login
    notebook_login()
